# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score

data=pd.read_csv('1.01. Simple linear regression.csv')
data.head()
# Out:
#     SAT   GPA
# 0  1714  2.40
# 1  1664  2.52
# 2  1760  2.54
# 3  1685  2.74
# 4  1693  2.83

# %%
print("Missing values : \n",data.isnull().sum())
# Out:
# Missing values :
#  SAT    0
# GPA    0
# dtype: int64

# %%
x=data[['SAT']]
y=data['GPA']
model=LinearRegression()
model.fit(x,y)
y_pred=model.predict(x)
print("\nRegression Intercept:", model.intercept_)
print("Regression Coefficient:", model.coef_[0])
# Out:
# Regression Intercept: 0.27504029966028076
# Regression Coefficient: 0.0016556880500928138

# %%
rss=mean_squared_error(y,y_pred)*len(y)
r2=r2_score(y,y_pred)
print("\nResidual Sum of Squares (RSS):", rss)
print("Coefficient of Determination (R²):", r2)
# Out:
# Residual Sum of Squares (RSS): 3.6372727995805025
# Coefficient of Determination (R²): 0.40600391479679765

# %%
plt.figure(figsize=(10,6))
plt.scatter(x,y,color='blue',label='Data Points')
plt.plot(x,y_pred,color='red',linewidth=2,label='Regression Line')
plt.xlabel("SAT Score")
plt.ylabel("GPA")
plt.title("Relationship between SAT score and GPA")
plt.legend()
plt.show()
