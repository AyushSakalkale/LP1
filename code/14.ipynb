# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score

data=pd.read_csv('advertising.csv')
data.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
print("Missing values : ",data.isnull().sum())
# Out:
# Missing values :  TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
x=data[['Newspaper']]
y=data['Sales']
model=LinearRegression()
model.fit(x,y)
y_pred=model.predict(x)

# %%
print("Regressing coefficient : ",model.coef_[0])
print("Coefficient od Determination : ",model.intercept_)
# Out:
# Regressing coefficient :  0.03832399510524274
# Coefficient od Determination :  13.959548653554414

# %%
rss=mean_squared_error(y,y_pred)*len(y)
r2=r2_score(y,y_pred)
print("Residual Sum of Squares (RSS):", rss)
print("Coefficient of Determination (R²):", r2)
# Out:
# Residual Sum of Squares (RSS): 5417.354539511409
# Coefficient of Determination (R²): 0.024951369862864836

# %%
plt.figure(figsize=(10,6))
plt.scatter(x,y,color='blue',label='Actual Sales')
plt.plot(x,y_pred,color='red',label='Regression Line')
plt.xlabel("Newspaper Advertising Spending")
plt.ylabel("Product Sales")
plt.title("Liner Regression")
plt.legend()
plt.show()
